# %% [markdown]
# ## 『本次練習內容』
# #### 搭建一個能識別驗證碼的模型(CNN+CTC)

# %% [markdown]
# ## 『本次練習目的』
#   #### 了解如何結合CNN與CTC Loss
#   #### 有時間學員也可以延伸閱讀CNN+RNN+CTC模型
#   #### 沒有GPU的學員可以使用Colab，可以參考問答區的文章

# %%
# %tensorflow_version 2.x

## 使用Colab可先run這裡的code
#假如要連結自己的雲端硬碟再開啟
##from google.colab import drive
##drive.mount('/content/gdrive')
#檢查GPU
##!nvidia-smi
##安裝產生驗證碼的套件
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ## 記得先 pip install captcha

# %%
# !pip install captcha
# Out:
# Collecting captcha
#   Downloading https://files.pythonhosted.org/packages/90/fe/d4ddf1e6576073b5eaea76e9b2afa022c626212a30c871968480be3ccb7b/captcha-0.3-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 5.3MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from captcha) (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->captcha) (0.46)
# Installing collected packages: captcha
# Successfully installed captcha-0.3

# %% [markdown]
# ## 產生驗證碼

# %%
from captcha.image import ImageCaptcha
import matplotlib.pyplot as plt
import numpy as np
import random

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import string
##驗證碼包含0-10數字以及26個英文字母
characters = string.digits + string.ascii_uppercase
print(characters)

##設定產生圖片尺寸，以及總類別，n_class之所以要加一是為了留一個位置給Blank
width, height, n_len, n_class = 170, 80, 4, len(characters)+1

##設定產生驗證碼的generator
generator = ImageCaptcha(width=width, height=height)

##我們先練習固定長度4個字的驗證碼
random_str = ''.join([random.choice(characters) for j in range(4)])
img = generator.generate_image(random_str)

plt.imshow(img)
plt.title(random_str)
# Out:
# 0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ
# Text(0.5, 1.0, '8BGX')

# %% [markdown]
# ## 自己搭建一個CNN模型使得output feature Map 高度被壓縮成小於4，8<寬度<20
# #### 解答的output feature Map 為 (batch_size,1,13,32)

# %%
from tensorflow.keras import backend as K
from tensorflow import keras

##CTC Loss需要四個資訊，分別是
## Label
## 預測
## CNN OUTPUT寬度
## 預測影像所包含文字長度
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
rnn_size = 128

input_tensor = Input((height,width, 3))
x = input_tensor

# 自己設計CNN層
x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D()(x)

x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D()(x)

x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D()(x)

x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = Conv2D(32, 3, 1, activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 1))(x)


##記錄輸出CNN尺寸，loss部分需要這個資訊
##conv_shape=(Batch_size,輸出高度,輸出寬度,輸出深度)
conv_shape = x.get_shape()

##從(Batch_size,輸出高度,輸出寬度,輸出深度)變成(Batch_size,輸出寬度,輸出深度*輸出高度)，以符合ctc loss需求
x = Reshape(target_shape=(int(conv_shape[2]), int(conv_shape[1]*conv_shape[3])))(x)

x = Dense(32, activation='relu')(x)

x = Dropout(0.25)(x)
x = Dense(n_class, activation='softmax')(x)


##包裝用來預測的model
base_model = Model(inputs=input_tensor, outputs=x)


##設定要給CTC Loss的資訊
labels = Input(name='the_labels', shape=[n_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), 
                  name='ctc')([x, labels, input_length, label_length])

##這裡的model是用來計算loss
model = Model(inputs=[input_tensor, labels, input_length, label_length], outputs=[loss_out])

##之所以要lambda y_true, y_pred: y_pred是因為我們的loss已經包在網路裡，會output:y_true, y_pred，而我們只需要y_pred
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='SGD')

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 170, 3)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 78, 168, 32)  896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 78, 168, 32)  128         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 76, 166, 32)  9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 76, 166, 32)  128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 38, 83, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 36, 81, 32)   9248        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 36, 81, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 34, 79, 32)   9248        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 34, 79, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 17, 39, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 15, 37, 32)   9248        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15, 37, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 13, 35, 32)   9248        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 13, 35, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 6, 17, 32)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 15, 32)    9248        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 15, 32)    128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 2, 13, 32)    9248        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 2, 13, 32)    128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 13, 32)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 13, 32)       0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 13, 32)       1056        reshape[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 13, 32)       0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 13, 37)       1221        dropout[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 4)]          0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense_1[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 68,933
# Trainable params: 68,421
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
##設計generator產生training data
## 產生包含要給loss的資訊
## X=輸入影像
## np.ones(batch_size)*int(conv_shape[2])=CNN輸出feature Map寬度
## np.ones(batch_size)*n_len=字串長度(可浮動)

def gen(width, height, conv_shape, batch_size=128, n_len=4):
    X = np.zeros((batch_size, height, width, 3), dtype=np.uint8)
    y = np.zeros((batch_size, n_len), dtype=np.uint8)
    while True:
        generator = ImageCaptcha(width=width, height=height)
        for i in range(batch_size):
            random_str = ''.join([random.choice(characters) for j in range(n_len)])
            X[i] = np.array(generator.generate_image(random_str))
            y[i] = [characters.find(x) for x in random_str]
        yield [X, y, np.ones(batch_size)*int(conv_shape[2]), np.ones(batch_size)*n_len], np.ones(batch_size)

# %%
next_ge = gen(width=width, height=height, conv_shape=conv_shape, batch_size=1, n_len=n_len)
test_ge = next(next_ge)
plt.imshow(test_ge[0][0][0])
print('X shape:', test_ge[0][0].shape)
print('Label: ', test_ge[0][1][0])
print('CNN輸出寬度: ', test_ge[0][2])
print('字串長度(可浮動): ', test_ge[0][3])
# Out:
# X shape: (1, 80, 170, 3)
# Label:  [17  1  7 31]
# CNN輸出寬度:  [13.]
# 字串長度(可浮動):  [4.]

# %% [markdown]
# ## 開始訓練

# %%
model.fit(gen(width=width, height=height, conv_shape=conv_shape, batch_size=32, n_len=n_len), steps_per_epoch=300, epochs=60)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 300 steps
# Epoch 1/60
# 300/300 [==============================] - 46s 152ms/step - loss: 15.8490
# Epoch 2/60
# 300/300 [==============================] - 38s 128ms/step - loss: 13.3875
# Epoch 3/60
# 300/300 [==============================] - 38s 127ms/step - loss: 9.9270
# Epoch 4/60
# 300/300 [==============================] - 38s 127ms/step - loss: 7.6235
# Epoch 5/60
# 300/300 [==============================] - 38s 127ms/step - loss: 6.2618
# Epoch 6/60
# 300/300 [==============================] - 38s 126ms/step - loss: 5.6859
# Epoch 7/60
# 300/300 [==============================] - 38s 125ms/step - loss: 5.1246
# Epoch 8/60
# 300/300 [==============================] - 38s 126ms/step - loss: 4.6431
# Epoch 9/60
# 300/300 [==============================] - 38s 125ms/step - loss: 4.6229
# Epoch 10/60
# 300/300 [==============================] - 38s 127ms/step - loss: 4.3828
# Epoch 11/60
# 300/300 [==============================] - 38s 126ms/step - loss: 4.2759
# Epoch 12/60
# 300/300 [==============================] - 38s 127ms/step - loss: 4.3168
# Epoch 13/60
# 300/300 [==============================] - 38s 126ms/step - loss: 4.1564
# Epoch 14/60
# 300/300 [==============================] - 38s 128ms/step - loss: 3.9552
# Epoch 15/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.9911
# Epoch 16/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.9169
# Epoch 17/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.9001
# Epoch 18/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.9098
# Epoch 19/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.8186
# Epoch 20/60
# 300/300 [==============================] - 38s 125ms/step - loss: 3.5724
# Epoch 21/60
# 300/300 [==============================] - 38s 125ms/step - loss: 3.6237
# Epoch 22/60
# 300/300 [==============================] - 38s 125ms/step - loss: 3.5174
# Epoch 23/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.6135
# Epoch 24/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.4940
# Epoch 25/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.6098
# Epoch 26/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.6436
# Epoch 27/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.4334
# Epoch 28/60
# 300/300 [==============================] - 37s 123ms/step - loss: 3.3279
# Epoch 29/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.7032
# Epoch 30/60
# 300/300 [==============================] - 38s 125ms/step - loss: 3.4821
# Epoch 31/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.4847
# Epoch 32/60
# 300/300 [==============================] - 37s 123ms/step - loss: 3.3622
# Epoch 33/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.3931
# Epoch 34/60
# 300/300 [==============================] - 37s 123ms/step - loss: 3.3090
# Epoch 35/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.1362
# Epoch 36/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.2931
# Epoch 37/60
# 300/300 [==============================] - 37s 123ms/step - loss: 3.1954
# Epoch 38/60
# 300/300 [==============================] - 37s 125ms/step - loss: 2.9512
# Epoch 39/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.1337
# Epoch 40/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.1774
# Epoch 41/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.0837
# Epoch 42/60
# 300/300 [==============================] - 37s 125ms/step - loss: 2.9556
# Epoch 43/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.2640
# Epoch 44/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.2466
# Epoch 45/60
# 300/300 [==============================] - 37s 124ms/step - loss: 3.0536
# Epoch 46/60
# 300/300 [==============================] - 37s 125ms/step - loss: 3.0071
# Epoch 47/60
# 300/300 [==============================] - 37s 125ms/step - loss: 2.8326
# Epoch 48/60
# 300/300 [==============================] - 37s 123ms/step - loss: 3.0962
# Epoch 49/60
# 300/300 [==============================] - 38s 128ms/step - loss: 2.7526
# Epoch 50/60
# 300/300 [==============================] - 37s 125ms/step - loss: 2.8450
# Epoch 51/60
# 300/300 [==============================] - 38s 125ms/step - loss: 2.7192
# Epoch 52/60
# 300/300 [==============================] - 37s 124ms/step - loss: 2.7429
# Epoch 53/60
# 300/300 [==============================] - 38s 125ms/step - loss: 2.7201
# Epoch 54/60
# 300/300 [==============================] - 38s 125ms/step - loss: 2.7052
# Epoch 55/60
# 300/300 [==============================] - 38s 126ms/step - loss: 2.5823
# Epoch 56/60
# 300/300 [==============================] - 37s 125ms/step - loss: 2.6281
# Epoch 57/60
# 300/300 [==============================] - 38s 125ms/step - loss: 2.5189
# Epoch 58/60
# 300/300 [==============================] - 37s 124ms/step - loss: 2.5150
# Epoch 59/60
# 300/300 [==============================] - 38s 125ms/step - loss: 2.7057
# Epoch 60/60
# 300/300 [==============================] - 37s 124ms/step - loss: 2.7651

# %% [markdown]
# ## 預測

# %%
# for what?
# characters2 = characters + ' '

[X_test, y_test, _, _], _  = next(gen(width=width, height=height, conv_shape=conv_shape, batch_size=1, n_len=n_len))
y_pred = base_model.predict(X_test)
##用ctc_decode得到解答，自己寫可以參考下方
out = K.get_value(K.ctc_decode(y_pred, input_length=np.ones(y_pred.shape[0])*y_pred.shape[1], )[0][0])
out = ''.join([characters[x] for x in out[0]])
y_true = ''.join([characters[x] for x in y_test[0]])

plt.imshow(X_test[0])
plt.title('pred:' + str(out) + '\ntrue: ' + str(y_true))

argmax = np.argmax(y_pred, axis=2)[0]
# Out:
# WARNING:tensorflow:From /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/backend.py:5811: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %% [markdown]
# ## 自己寫 decode CTC

# %%
## 其中0代表預測為空格，如果預測相同字符之間沒有空格要移除
word = ''
n = ''
print(y_pred[0].argmax(1))
for single_result in y_pred[0].argmax(1):
    if single_result != 36:
        if n != single_result:
            word += characters[single_result]
    n = single_result
print(word)
# Out:
# [36 36 24 36 36  4 11 11 11 36 26 26 26]
# O4BQ

# %% [markdown]
# ## 額外參考：加入RNN的神經網路

# %%
rnn_size = 128

input_tensor = Input((height,width, 3))
x = input_tensor
for i in range(4):
    x = Convolution2D(32, 3, 1, activation='relu')(x)
    x = BatchNormalization(axis=-1)(x)
    x = Convolution2D(32, 3, 1, activation='relu')(x)
    x = BatchNormalization(axis=-1)(x)
    if i < 3:
        x = MaxPooling2D(pool_size=(2, 2))(x)
    else:
        x = MaxPooling2D(pool_size=(2, 1))(x)


conv_shape = x.get_shape()
x = Reshape(target_shape=(int(conv_shape[2]), int(conv_shape[1]*conv_shape[3])))(x)

x = Dense(32, activation='relu')(x)

gru_1 = GRU(rnn_size, return_sequences=True, kernel_initializer='he_normal', name='gru1')(x)
gru_1b = GRU(rnn_size, return_sequences=True, go_backwards=True, 
             kernel_initializer='he_normal', name='gru1_b')(x)
gru1_merged = add([gru_1, gru_1b])

gru_2 = GRU(rnn_size, return_sequences=True, kernel_initializer='he_normal', name='gru2')(gru1_merged)
gru_2b = GRU(rnn_size, return_sequences=True, go_backwards=True, 
             kernel_initializer='he_normal', name='gru2_b')(gru1_merged)
x = Concatenate()([gru_2, gru_2b])

x = Dropout(0.25)(x)
x = Dense(n_class, kernel_initializer='he_normal', activation='softmax')(x)

base_model = Model(inputs=input_tensor, outputs=x)

labels = Input(name='the_labels', shape=[n_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), 
                  name='ctc')([x, labels, input_length, label_length])

model = Model(inputs=[input_tensor, labels, input_length, label_length], outputs=[loss_out])
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='Adam')

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 80, 170, 3)] 0
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 78, 168, 32)  896         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 78, 168, 32)  128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 76, 166, 32)  9248        batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 76, 166, 32)  128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 38, 83, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 36, 81, 32)   9248        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 36, 81, 32)   128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 34, 79, 32)   9248        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 34, 79, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 17, 39, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 15, 37, 32)   9248        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 15, 37, 32)   128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 13, 35, 32)   9248        batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 13, 35, 32)   128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 6, 17, 32)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 15, 32)    9248        max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 15, 32)    128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 2, 13, 32)    9248        batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 2, 13, 32)    128         conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 1, 13, 32)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 13, 32)       0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 13, 32)       1056        reshape_4[0][0]
# __________________________________________________________________________________________________
# gru1 (GRU)                      (None, 13, 128)      62208       dense_7[0][0]
# __________________________________________________________________________________________________
# gru1_b (GRU)                    (None, 13, 128)      62208       dense_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 13, 128)      0           gru1[0][0]
#                                                                  gru1_b[0][0]
# __________________________________________________________________________________________________
# gru2 (GRU)                      (None, 13, 128)      99072       add_2[0][0]
# __________________________________________________________________________________________________
# gru2_b (GRU)                    (None, 13, 128)      99072       add_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 13, 256)      0           gru2[0][0]
#                                                                  gru2_b[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 13, 256)      0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 13, 37)       9509        dropout_3[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 4)]          0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense_8[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 399,781
# Trainable params: 399,269
# Non-trainable params: 512
# __________________________________________________________________________________________________
