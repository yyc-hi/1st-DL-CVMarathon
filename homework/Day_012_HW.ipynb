# %% [markdown]
# ## 『作業內容』
# ####   依照指示，透過調整Padding、Strides參數控制輸出Feature map大小

# %% [markdown]
# ## 『目標』
# ####   了解輸出feature map尺寸變化原理

# %%
# %tensorflow_version 2.x

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model


##kernel size=(6,6)
##kernel數量：32

filters = 32
kernel_size = (6,6)

## Same padding、strides=(1,1)
inputs = Input(shape=(13,13,1))
x = Convolution2D(filters, kernel_size, strides=(1,1), padding='same')(inputs)
model = Model(inputs=inputs, outputs=x)
model.summary()

## Same padding、strides=(2,2)
inputs = Input(shape=(13,13,1))
x = Convolution2D(filters, kernel_size, strides=(2,2), padding='same')(inputs)
model = Model(inputs=inputs, outputs=x)
model.summary()

## Valid padding、strides=(1,1)
inputs = Input(shape=(13,13,1))
x = Convolution2D(filters, kernel_size, strides=(1,1), padding='valid')(inputs)
model = Model(inputs=inputs, outputs=x)
model.summary()

## Valid padding、strides=(2,2)
inputs = Input(shape=(13,13,1))
x = Convolution2D(filters, kernel_size, strides=(2,2), padding='valid')(inputs)
model = Model(inputs=inputs, outputs=x)
model.summary()
# Out:
# TensorFlow 2.x selected.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 13, 13, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 13, 13, 32)        1184
# ...
# Total params: 1,184
# Trainable params: 1,184
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 13, 13, 1)]       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 32)          1184
# ...
# Total params: 1,184
# Trainable params: 1,184
# Non-trainable params: 0
# _________________________________________________________________
# ...
